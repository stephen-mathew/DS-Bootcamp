# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfIris = sns.load_dataset('iris')

# %%
dfIris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
dfIris.plot()
# Out:
# <AxesSubplot:>

# %%
dfIris.plot(kind='area',alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
dfIris.plot(kind='area',alpha=0.4,stacked=False)
# Out:
# <AxesSubplot:>

# %%
dfIris.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
dfIris.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
dfIris.plot.scatter(x='sepal_length',y='petal_length', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
dfIris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
dfIris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=dfIris['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
dfIris.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,cmap='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2 + y**2))

# %%
x = np.linspace(-1,6,30)
y = np.linspace(-1,6,30)
z = x + y

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(dfIris['sepal_length'],dfIris['sepal_width'],dfIris['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
dfIris.plot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
dfIris.plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
(
    dfIris
    .iloc[5:11]
    .plot(kind='bar')
)
# Out:
# <AxesSubplot:>

# %%
(
    dfIris
    .iloc[5:11]
    .plot(kind='barh')
)
# Out:
# <AxesSubplot:>

# %%
(
    dfIris
    .plot(kind='hist',figsize=(15,7))
)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
(
    dfIris['sepal_length']
    .plot(kind='hist',figsize=(15,7))
)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
(
    dfIris
    .hist(figsize=(15,7),color='g',alpha=0.9)
)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
(
    dfIris
    .hist(figsize=(15,7),alpha=0.9)
)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dfIris.iplot()
# Out:
# <div>                            <div id="941599c7-5b13-49c6-9149-f6231c0b9333" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
(
    dfIris
    .iplot(x='sepal_length',y='sepal_width',kind='scatter',mode='markers')
)
# Out:
# <div>                            <div id="eb4d9ed1-b154-4142-b58d-2c4e1d51883d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
(
    dfIris
    .iplot(x='sepal_length',y='sepal_width',kind='bubble',size='petal_length')
)
# Out:
# <div>                            <div id="e40a95ce-d7f9-407b-8929-61d317727783" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
(
    dfIris
    .iplot(x='sepal_length',y='sepal_width',z='petal_width',kind='bubble3d',size='petal_length')
)
# Out:
# <div>                            <div id="effd4b39-13b1-478e-8b7e-3da3e5a29ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dfTips = sns.load_dataset('tips')

# %%
dfTips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
(
    dfTips
    .plot(x='total_bill',y='tip',kind='scatter')
)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
(
    dfTips
    .iplot(x='total_bill',y='tip',kind='scatter',mode='markers')
)
# Out:
# <div>                            <div id="0bc15adc-335d-4e5d-b301-079e7096a902" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x='total_bill',y='tip',data=dfTips)

# %%
sns.relplot(x='total_bill',y='tip',data=dfTips, hue='smoker')

# %%
(
    sns
    .relplot(x='total_bill',y='tip',data=dfTips, hue='time')
)

# %%
(
    sns
    .relplot(x='total_bill'
             ,y='tip'
             ,data=dfTips
             , hue='time'
             ,style='smoker'
            )
)

# %%
(
    sns
    .relplot(x='total_bill'
             ,y='tip'
             ,data=dfTips
             , hue='time'
             ,style='sex'
            )
)

# %%
(
    sns
    .relplot(x='total_bill'
             ,y='tip'
             ,data=dfTips
             , col='time'
            )
)

# %%
(
    sns
    .relplot(x='sepal_length'
             ,y='sepal_width'
             ,data=dfIris
             ,col='species'
            )
)

# %%
(
    sns
    .relplot(x='total_bill'
             ,y='tip'
             ,data=dfTips
             ,col='day'
            )
)

# %%
(
    sns
    .catplot(x='day'
             ,y='total_bill'
             ,data=dfTips
            )
)

# %%
(
    sns
    .pairplot(data=dfTips
            )
)

# %%
(
    sns
    .pairplot(dfIris
            )
)

# %%
dfIris.scatter_matrix()
# Out:
# <div>                            <div id="bc717e6f-a643-4283-bb9e-08f9d35abef6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x='total_bill',y='tip',data=dfTips)

# %%
sns.jointplot(x=dfTips['total_bill'],y=dfTips['tip'])

# %%
(
    sns
    .jointplot(x=dfTips['total_bill']
               ,y=dfTips['tip']
              ,kind='hex')
)

# %%
(
    sns
    .pairplot(dfTips)
)

# %%
(
    sns.regplot(x=dfTips['total_bill']
               ,y=dfTips['tip'])
)
sns.set(rc={'figure.figsize':(15,7)})
